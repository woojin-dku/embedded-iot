# %%
#1. Connect google drive
from google.colab import drive

drive.mount('/content/gdrive')

# %%
#2. List google drive
# !ls /content/gdrive

# %%
#3. Move to directory to use
cd /content/gdrive/Shareddrives/단국대/lecture-repos/

# %%
print("Download Embedded & IoT Lecture Repository")
# !git clone https://github.com/woojin-dku/embedded-iot
